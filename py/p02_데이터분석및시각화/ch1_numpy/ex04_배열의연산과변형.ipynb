# %%
# 배열의 연산과 변형
import numpy as np

# 배열 생성
arr = np.arange(1, 5)
arr
# Out:
# array([1, 2, 3, 4])

# %%
## 벡터화 연산(Vectorized Operation)
arr + 2
# Out:
# array([3, 4, 5, 6])

# %%
arr * 2
# Out:
# array([2, 4, 6, 8])

# %%
# 리스트
list = [1, 2, 3, 4]
list
# Out:
# [1, 2, 3, 4]

# %%
list * 2  # +는 실행이 안됨
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
arr1 = np.arange(5, 9)
arr1
# Out:
# array([5, 6, 7, 8])

# %%
arr + arr1
# Out:
# array([ 6,  8, 10, 12])

# %%
list1 = [5, 6, 7, 8]
list + list1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
