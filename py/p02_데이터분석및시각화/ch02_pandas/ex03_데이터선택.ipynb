# %% [markdown]
# ## 1. 기본 인덱싱과 슬라이싱

# %%
import pandas as pd

# 예시 데이터 생성
sales_data = pd.DataFrame({
    'product': ['노트북', '마우스', '키보드', '모니터', '스피커'],
    'price': [1200000, 25000, 80000, 350000, 120000],
    'quantity': [10, 50, 30, 15, 25],
    'category': ['전자제품', '주변기기', '주변기기', '전자제품', '주변기기']
})
sales_data
# Out:
#   product    price  quantity category
# 0     노트북  1200000        10     전자제품
# 1     마우스    25000        50     주변기기
# 2     키보드    80000        30     주변기기
# 3     모니터   350000        15     전자제품
# 4     스피커   120000        25     주변기기

# %% [markdown]
# ### 1) 단일 컬럼 선택

# %%
# 단일 컬럼 선택
product_series = sales_data['product']
print(product_series)
# Out:
# 0    노트북
# 1    마우스
# 2    키보드
# 3    모니터
# 4    스피커
# Name: product, dtype: str

# %%
# 다중 컬럼 선택
price_quantity = sales_data[['product', 'price', 'quantity']]
print(price_quantity)
# Out:
#   product    price  quantity
# 0     노트북  1200000        10
# 1     마우스    25000        50
# 2     키보드    80000        30
# 3     모니터   350000        15
# 4     스피커   120000        25

# %%
# 행 슬라이싱 (첫 3개 행 선택)
first_three = sales_data[0:3]
print(first_three)
# Out:
#   product    price  quantity category
# 0     노트북  1200000        10     전자제품
# 1     마우스    25000        50     주변기기
# 2     키보드    80000        30     주변기기

# %% [markdown]
# ## 2. 조건부 선택 (boolean indexing)

# %% [markdown]
# ### 1) 가격이 100000원 이상인 제품 선택

# %%
# 가격이 100000원 이상인 제품 선택
expensive_products = sales_data[sales_data['price'] >= 100000]
print(expensive_products)
# Out:
#   product    price  quantity category
# 0     노트북  1200000        10     전자제품
# 3     모니터   350000        15     전자제품
# 4     스피커   120000        25     주변기기

# %% [markdown]
# ### 2) query 메서드 사용

# %%
# query 메서드 사용
high_quantity = sales_data.query('quantity > 20')
print(high_quantity)
# Out:
#   product   price  quantity category
# 1     마우스   25000        50     주변기기
# 2     키보드   80000        30     주변기기
# 4     스피커  120000        25     주변기기

# %% [markdown]
# ## 3. loc과 iloc을 활용한 라벨/위치 기반 선택

# %%
# 인덱스 설정
sales_data_indexed = sales_data.set_index('product')
print(sales_data_indexed)
# Out:
#            price  quantity category
# product
# 노트북      1200000        10     전자제품
# 마우스        25000        50     주변기기
# 키보드        80000        30     주변기기
# 모니터       350000        15     전자제품
# 스피커       120000        25     주변기기

# %% [markdown]
# ### 1) loc

# %%
# 특정 제품의 가격 선택
# df.loc[행, 열]: 라벨 기반 선택
notebook_info = sales_data_indexed.loc['노트북', 'price']
print(f"노트북 가격: {notebook_info:,}원")
# Out:
# 노트북 가격: 1,200,000원

# %% [markdown]
# ### 2) loc - 여러 제품

# %%
# 여러 제품의 가격과 수량 선택
selected_data = sales_data_indexed.loc[['노트북', '마우스'], ['price', 'quantity']]
print(selected_data)
# Out:
#            price  quantity
# product
# 노트북      1200000        10
# 마우스        25000        50

# %% [markdown]
# ### 3) iloc

# %%
# iloc: 위치 기반 선택 ( 첫 번째와 세 번째 행, 두 번째와 세 번째 컬럼)
# df.iloc[행index, 열index]
position_data = sales_data.iloc[[0, 2], [1, 2]]
print(sales_data)
print(position_data)
# Out:
#   product    price  quantity category
# 0     노트북  1200000        10     전자제품
# 1     마우스    25000        50     주변기기
# 2     키보드    80000        30     주변기기
# 3     모니터   350000        15     전자제품
# 4     스피커   120000        25     주변기기
#      price  quantity
# 0  1200000        10
# 2    80000        30

# %% [markdown]
# ## 4. 다중 조건 선택

# %% [markdown]
# ### 1) 가격이 50,000원 이상이면서 수량이 20개 이상인 제품

# %%
# 가격이 50000원 이상이면서 수량이 20개 이상인 제품
filtered_data = sales_data[(sales_data['price'] >= 50000) & (sales_data['quantity'] >= 20)]
print(filtered_data)
# Out:
#   product   price  quantity category
# 2     키보드   80000        30     주변기기
# 4     스피커  120000        25     주변기기

# %% [markdown]
# ### 2) 전자제품이거나 가격이 30,000원 이하인 제품

# %%
# 전자제품(category)이거나 가격이 30,000원 이하인 제품
electronic_or_cheap = sales_data[(sales_data['category'] == '전자제품') | (sales_data['price'] <= 30000)]
print(electronic_or_cheap)
# Out:
#   product    price  quantity category
# 0     노트북  1200000        10     전자제품
# 1     마우스    25000        50     주변기기
# 3     모니터   350000        15     전자제품
