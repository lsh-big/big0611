# %%
import matplotlib.pyplot as plt

# 1. x, y 데이터
x = [10, 20, 30]
y = [15, 24, 18]

plt.bar(x, y, width=5)
# xlim: x축 limit(범위)
plt.xlim(0, 80)
# plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40])
# plt.xticks(range(0, 81, 5))
# Out:
# (0.0, 80.0)
